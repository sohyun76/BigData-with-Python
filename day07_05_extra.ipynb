# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# 시각화 함수 호출 시에 바로 notebook에 표현하기
# %matplotlib inline

# %%
# 랜덤 값 100개 추출하기
np.random.seed() # seed 씨앗. 랜덤의 기본이 되는 값을 지정

# np.random.randint(시작값, 끝값, 갯수)
a = np.random.randint(-80, 100, 50).cumsum()
b = np.random.randint(-80, 100, 50).cumsum()
c = np.random.randint(-80, 100, 50).cumsum()

# %%
df1 = pd.DataFrame(data={'stock_korea':a, 'stock_hclass':b, 'stock_4':c}
                  , index=pd.date_range('1/1/2019', periods=50)
                  )

# %%
df1.head()
# Out:
#             stock_korea  stock_hclass  stock_4
# 2019-01-01          -37            -8       21
# 2019-01-02          -97            -1      -44
# 2019-01-03         -118            44      -76
# 2019-01-04          -25           138       21
# 2019-01-05          -85           106       86

# %%
df1.plot()

# %%
# 폰트 변경을 위한 모둘 불러오기
import matplotlib as mpl
import matplotlib.font_manager as fm

# %%
# 사용할 수 있는 font 검색하기
# fm.fontManager.ttflist

# %%
# 현재 사용 중인 font 확인
plt.rcParams['font.family']
# Out:
# ['sans-serif']

# %%
# font 교체하기
plt.rcParams['font.family'] = 'Malgun Gothi'

# %%
# 한글은 기본적으로 아나콘다에서 깨집니다. 
df1.plot()
plt.title('주식 가격 시각화')
# Out:
# Text(0.5, 1.0, '주식 가격 시각화')
# findfont: Font family ['Malgun Gothi'] not found. Falling back to DejaVu Sans.
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 49885 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 44032 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 44201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\user\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:214: RuntimeWarning: Glyph 49884 missing from current font.
# ...
